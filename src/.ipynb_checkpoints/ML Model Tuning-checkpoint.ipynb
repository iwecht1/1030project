# %% [markdown]
# <h1><center>Solving for Happiness - Machine Learning Model Tuning</center></h1>

# %%
# import libraries to be used throughout project
import pandas as pd
import numpy as np
import matplotlib 
import math
from matplotlib import pylab as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import pickle

# preprocess with pipeline and columntransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

import warnings

# %%
# strings to automate dataset load-ins
front = '../data/'
back_other = '_other.csv'
back_test = '_test.csv'

# dictionary to hold scores of all models across lags 
score_dict = {}

# dictionary to hold std of scores for all models across lags 
std_scores = {}

# dictionary to hold model results
results = {}

# %%
# lists to grab right files from directory 
X = ['X1','X2','X3','X4','X5']
y = ['y1','y2','y3','y4','y5']

# lists to save all X_other, X_test, y_other, and y_test across all lags 
X_other_list = []
X_test_list = []
y_other_list = []
y_test_list = []

# number of lagged datasets to test with 
num_lags = 5

# save all lagged dataframes to list
for i in range(num_lags):
    
    # import laged dataframe 
    X_other = pd.read_csv(front + X[i] + back_other)
    X_other.drop(['Unnamed: 0'],axis=1,inplace=True)

    X_test = pd.read_csv(front + X[i] + back_test)
    X_test.drop(['Unnamed: 0'],axis=1,inplace=True)

    y_other = pd.read_csv(front + y[i] + back_other)
    y_other.drop(['Unnamed: 0'],axis=1,inplace=True)

    y_test = pd.read_csv(front + y[i] + back_test)
    y_test.drop(['Unnamed: 0'],axis=1,inplace=True)

    # convert dataframes to series 
    y_test = y_test['Target Score']
    y_other = y_other['Target Score']

    X_other_list.append(X_other)
    X_test_list.append(X_test)
    y_other_list.append(y_other)
    y_test_list.append(y_test)

# %% [markdown]
# **Lagging Trade-offs:** The below barplots illustrate the trade-offs incurred from lagging our feature matrix. With each additional lag, the model gains 5 more features per datapoint, as it is able to look one year further back into the past for each metric. However, by increasing our lags, we are forced to drop datapoints from our dataset as we do not have information prior to 2005.

# %%
# display change in dataset size from lagged experiments 
dataset = []
features = []

for i in range(5):
    dataset.append(X_other_list[i].shape[0])
    features.append(X_other_list[i].shape[1])
    
sns.set_style('darkgrid')
sns.set_palette('Set2')


sns.barplot(y=dataset,x=[1,2,3,4,5])

plt.title('Change in Amount of Datapoints',weight='bold')
plt.xlabel('Number of Lagged Years',weight='bold')
plt.ylabel('Number of Datapoints',weight='bold')

plt.savefig(fname='../figures/datapoint_change',format='png')

plt.show()

# %%
sns.barplot(y=features,x=[1,2,3,4,5])

plt.title('Change in Amount of Features',weight='bold')
plt.xlabel('Number of Lagged Years',weight='bold')
plt.ylabel('Number of Features Per Datapoint',weight='bold')

plt.savefig(fname='../figures/feature_change',format='png')

plt.show()

# %% [markdown]
# <h2>Baseline Regression Model</h2>

# %% [markdown]
# The below analysis examines the baseline RMSE metric for a constant regression model. This metric is calculated by predicting the average value of the target variable for each of the datapoints. This baseline will be used to judge each of the machine learning algorithms below. A 'good' model should produce a RMSE score that is at least lower than the baseline metric calculated here.

# %%
# create mean series
pred_avg = y_test.mean()

avg_list = np.ones(len(y_test))*pred_avg
y_avg = pd.Series(avg_list)

# calculate the baseline RMSE metric
mse_base = mean_squared_error(y_test,y_avg)
rmse_base = math.sqrt(mse_base)

print('Baseline RMSE Score: {:.4}'.format(rmse_base))
# Out:
# Baseline RMSE Score: 0.9885

# %% [markdown]
# <h2> General Machine Learning Algorithm </h2>

# %% [markdown]
# The below code creates a PredefinedSplit object, which will be used to maintain the data integrity of the train and validation sets during the GrindSearchCV training process.

# %%
# import predefinedsplit to maintain data integrity during cv
from sklearn.model_selection import PredefinedSplit

# list to save all predefined splits for each lagged set 
all_ps = []

# indexes for the different train sets 
train_index = [470,423,376,329,282]

# The indices which have zero or positive values, will be kept in validation during the grid split
val_indexes = np.full((94,), 0, dtype=int)

# create a PredefinedSplit object for each dataset 
for i in range(num_lags):
    
    # The indices which have the value -1 will be kept in train during the grid split 
    train_indexes = np.full((train_index[i],), -1, dtype=int)

    test_fold = np.append(train_indexes, val_indexes)

    # create a predefinedsplit instance that has the indexes of the train and val sets 
    ps = PredefinedSplit(test_fold)
    
    # add object to the all ps list      
    all_ps.append(ps)

# Check how many splits will be done, based on test_fold - 1 split is expected for each dataset
for i in range(5):
    print('Number of splits to be created by ps:',all_ps[i].get_n_splits())
# Out:
# Number of splits to be created by ps: 1
# Number of splits to be created by ps: 1
# Number of splits to be created by ps: 1
# Number of splits to be created by ps: 1
# Number of splits to be created by ps: 1

# %% [markdown]
# The below code creates a preprocessor, which will be passed to GrindSearchCV in order to preprocess the dataset before completing the training and validation of our machine learning algorithm.

# %%
# features for standardscaling preprocessing - lag1
num_ftrs1 = ['Target Year', 
            'Population lag 1 year', 'Population Current',
            'Life Ex lag 1 year','Life Ex Current', 
            'GDP lag 1 year', 'GDP Current', 
            'GDP_cap lag 1 year', 'GDP_cap Current',
            'CO2 lag 1 year', 'CO2 Current',
            'Happy lag 1 year']

# features for standardscaling preprocessing - lag2
num_ftrs2 = ['Target Year', 
            'Population lag 2 years', 'Population lag 1 year', 'Population Current',
            'Life Ex lag 2 years', 'Life Ex lag 1 year','Life Ex Current', 
            'GDP lag 2 years','GDP lag 1 year', 'GDP Current', 
            'GDP_cap lag 2 years', 'GDP_cap lag 1 year', 'GDP_cap Current',
            'CO2 lag 2 years', 'CO2 lag 1 year', 'CO2 Current',
            'Happy lag 2 years', 'Happy lag 1 year']


# features for standardscaling preprocessing - lag3
num_ftrs3 = ['Target Year', 
            'Population lag 3 years','Population lag 2 years', 'Population lag 1 year', 'Population Current',
            'Life Ex lag 3 years', 'Life Ex lag 2 years', 'Life Ex lag 1 year','Life Ex Current', 
            'GDP lag 3 years', 'GDP lag 2 years','GDP lag 1 year', 'GDP Current', 
            'GDP_cap lag 3 years','GDP_cap lag 2 years', 'GDP_cap lag 1 year', 'GDP_cap Current',
            'CO2 lag 3 years', 'CO2 lag 2 years', 'CO2 lag 1 year', 'CO2 Current',
            'Happy lag 3 years', 'Happy lag 2 years', 'Happy lag 1 year']

# features for standardscaling preprocessing - lag4
num_ftrs4 = ['Target Year', 
            'Population lag 4 years','Population lag 3 years','Population lag 2 years', 'Population lag 1 year', 'Population Current',
            'Life Ex lag 4 years','Life Ex lag 3 years', 'Life Ex lag 2 years', 'Life Ex lag 1 year','Life Ex Current', 
            'GDP lag 4 years','GDP lag 3 years', 'GDP lag 2 years','GDP lag 1 year', 'GDP Current', 
            'GDP_cap lag 4 years','GDP_cap lag 3 years','GDP_cap lag 2 years', 'GDP_cap lag 1 year', 'GDP_cap Current',
            'CO2 lag 4 years','CO2 lag 3 years', 'CO2 lag 2 years', 'CO2 lag 1 year', 'CO2 Current',
            'Happy lag 4 years','Happy lag 3 years', 'Happy lag 2 years', 'Happy lag 1 year']

# features for standardscaling preprocessing - lag4
num_ftrs5 = ['Target Year', 
            'Population lag 5 years','Population lag 4 years','Population lag 3 years','Population lag 2 years', 'Population lag 1 year', 'Population Current',
            'Life Ex lag 5 years','Life Ex lag 4 years','Life Ex lag 3 years', 'Life Ex lag 2 years', 'Life Ex lag 1 year','Life Ex Current', 
            'GDP lag 5 years','GDP lag 4 years','GDP lag 3 years', 'GDP lag 2 years','GDP lag 1 year', 'GDP Current', 
            'GDP_cap lag 5 years','GDP_cap lag 4 years','GDP_cap lag 3 years','GDP_cap lag 2 years', 'GDP_cap lag 1 year', 'GDP_cap Current',
            'CO2 lag 5 years','CO2 lag 4 years','CO2 lag 3 years', 'CO2 lag 2 years', 'CO2 lag 1 year', 'CO2 Current',
            'Happy lag 5 years','Happy lag 4 years','Happy lag 3 years', 'Happy lag 2 years', 'Happy lag 1 year']

# save all categories to a master list 
num_ftr_list = [num_ftrs1,num_ftrs2,num_ftrs3,num_ftrs4,num_ftrs5]

# %%
# feature for categorical preprocessing
cat_ftrs = ['Country']

# one-hot encoder
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse=False,handle_unknown='ignore'))])

# standard scaler
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

# list to save all preprocessors for each dataset 
preprocessors = []

for i in range(num_lags):
    # create a preprocessor from the collected the transformers
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, num_ftr_list[i]),
            ('cat', categorical_transformer, cat_ftrs)])
    
    # add preprocessor to master list       
    preprocessors.append(preprocessor)

# %% [markdown]
# The below function is a general purpose algorithm that will be used throughout this notebook to train and test various machine learning models. The function takes the train and validation sets (X_other, y_other), the test sets, an machine learning algorithm, and the parameter grid to tune.

# %%
# general function to find best models and test scores 
def MLpipe_RMSE(X_other,X_test,y_other,y_test,preprocessor,ps,ml_algo,para_grid,bestModels,bestScores,bestPara):

    # create pipe for modeling algorithm
    pipe = make_pipeline(preprocessor,ml_algo)

    # create grid to loop through hyperparameter combinations and collect results
    grid = GridSearchCV(pipe,param_grid=para_grid,scoring='neg_root_mean_squared_error',cv=ps,
                        return_train_score=False,n_jobs=-1,verbose=False)

    # fit the model onto other, this will be split between train and val based on ps 
    grid.fit(X_other,y_other)

    # save the hyperparameters that made for the best model         
    bestPara.append(grid.best_params_)

    # save the model
    bestModels.append(grid)

    # calculate and save the test score
    y_test_pred = bestModels[-1].predict(X_test)
    bestScores.append(math.sqrt(mean_squared_error(y_test,y_test_pred)))

    return bestModels, bestScores, bestPara, y_test_pred

# %%
# list of random states to test different models on 
random_states = [0,5,15,37,42,68,97,100,234,583]

# %% [markdown]
# <h2>Linear Regression Modeling - Lasso</h2>

# %%
#import lasso regression object 
from sklearn.linear_model import Lasso

# lists to hold best models and test scores      
l1_bestModels = []
l1_bestScores = []
l1_bestPara = []
# l1_y_pred = []

# hyperparameters to tune
param_grid = {
              'lasso__alpha': np.logspace(-30,10,21) # the alpha value for regularization
              } 

# initialize lasso model object
l1_mod = Lasso(max_iter=10000,random_state=0)

# calculate scores and find best models for all datasets 
for i in range(num_lags):
    # call function and save scores and models
    l1_bestModels, l1_bestScores, l1_bestPara, l1_y_pred = MLpipe_RMSE(X_other_list[i],X_test_list[i],
                                                                    y_other_list[i],y_test_list[i],preprocessors[i],all_ps[i],l1_mod,
                                                            param_grid, l1_bestModels,l1_bestScores,l1_bestPara)

# print results
print('Test score for Lasso (l1 Regularization):',np.average(l1_bestScores))
print('Standard deviation of test scores for l1:', np.std(l1_bestScores))

print('\nBest Parameters:')
for k,v in l1_bestPara[0].items():
    print('Alpha:',v)
    

# save test scores and their standard deviation 
std_scores['Lasso'] = np.std(l1_bestScores)
score_dict['Lasso'] = l1_bestScores
results['Lasso'] = l1_y_pred

# save model to directory
file = open('../results/lasso_model.save', 'wb')
pickle.dump((l1_bestModels[2],X_test_list[2],y_test_list[2]),file)
file.close()
# Out:
# /opt/anaconda3/envs/data1030/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.058e+01, tolerance: 5.302e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
print('Model Test Scores:')
score_dict
# Out:
# Model Test Scores:
# {'Lasso': [0.28173612860247454,
#   0.25937279313193673,
#   0.24906539970970298,
#   0.25149432610632483,
#   0.2500200175818385]}

# %% [markdown]
# <h2>Linear Regression Modeling - Ridge</h2>

# %%
# create l2 regularization model
from sklearn.linear_model import Ridge

# lists to hold best models and test scores      
l2_bestModels = []
l2_bestScores = []
l2_bestPara = []

# hyperparameters to tune
param_grid = {
              'ridge__alpha': np.logspace(-7,7,21) # the alpha value for regularization
              } 

# initialize lasso model object
l2_mod = Ridge(max_iter=10000000,random_state=0)

# calculate test scores and find best models for each dataset 
for i in range(num_lags):
    # call function and save scores and models
    l2_bestModels, l2_bestScores, l2_bestPara, l2_y_pred = MLpipe_RMSE(X_other_list[i],X_test_list[i],y_other_list[i],
                                                        y_test_list[i],preprocessors[i],all_ps[i],l2_mod,param_grid,
                                                        l2_bestModels,l2_bestScores,l2_bestPara)

# print results
print('Average test score for l2:',np.average(l2_bestScores))
print('Standard deviation of test scores for l2:', np.std(l2_bestScores))

print('\nBest Parameters:')
for k,v in l2_bestPara[0].items():
    print('Alpha:',v)


std_scores['Ridge'] = np.std(l2_bestScores)
score_dict['Ridge'] = l2_bestScores
results['Ridge'] = l2_y_pred

# save model to directory
file = open('../results/ridge_model.save', 'wb')
pickle.dump((l2_bestModels[2],X_test_list[2],y_test_list[2]),file)
file.close()
# Out:
# Average test score for l2: 0.2512418918210265
# Standard deviation of test scores for l2: 0.009240021981255746
#
# Best Parameters:
# Alpha: 5.011872336272715

# %%
print('Model Test Scores:')
score_dict
# Out:
# Model Test Scores:
# {'Lasso': [0.28173612860247454,
#   0.25937279313193673,
#   0.24906539970970298,
#   0.25149432610632483,
#   0.2500200175818385],
#  'Ridge': [0.26834974325425265,
#   0.2498607071922912,
#   0.24269001814201827,
#   0.243566072101859,
#   0.25174291841471147]}

# %% [markdown]
# <h2>Random Forest Regressor</h2>

# %%
# create random forest model
from sklearn.ensemble import RandomForestRegressor

# lists to hold best models and test scores      
rf_bestModels = []
rf_bestScores = []
rf_bestPara = []

# hyperparameters to tune
param_grid = {
              'randomforestregressor__max_depth': [1, 3, 5, 7, 10,15,20], # the max_depth of each tree
              'randomforestregressor__max_features': [0.15, 0.25, 0.5,0.75,1.0], # linearly spaced between 0.5 and 1
              }  

# train and test models for each random state
for state in random_states:
    # initialize model algo
    rf_mod = RandomForestRegressor(random_state=state)
    
    # calculate test scores and best models for each dataset      
    for i in range(num_lags):
        # call function and save scores and models
        rf_bestModels, rf_bestScores, rf_bestPara, rf_y_pred = MLpipe_RMSE(X_other_list[i],X_test_list[i],y_other_list[i],
                                                                y_test_list[i],preprocessors[i],all_ps[i],rf_mod,
                                                                param_grid,rf_bestModels,rf_bestScores,rf_bestPara)

# print results
print('Average test score for random forest:',np.average(rf_bestScores))
print('Standard deviation of test scores for random forest:', np.std(rf_bestScores))

# save standard deivation of test scores 
std_scores['Random Foresrt'] = np.std(rf_bestScores)
results['Random Forest'] = rf_y_pred

# save model to directory
file = open('../results/rf_model.save', 'wb')
pickle.dump((rf_bestModels[2],X_test_list[2],y_test_list[2]),file)
file.close()

print('\nBest Parameters:')
best_para = pd.DataFrame(rf_bestPara)   
best_para
# Out:
# Average test score for random forest: 0.2735027445777494
# Standard deviation of test scores for random forest: 0.014937409785338604
#
# Best Parameters:
#     randomforestregressor__max_depth  randomforestregressor__max_features
# 0                                  5                                 0.75
# 1                                 15                                 0.50
# 2                                 10                                 0.50
# 3                                  3                                 1.00
# 4                                 10                                 0.75
# 5                                  7                                 0.50
# 6                                 10                                 0.50
# 7                                 20                                 0.25
# 8                                  3                                 1.00
# 9                                 20                                 0.50
# ...

# %%
# create averages of test scores across all random states 
rf_avgs = []
k=0
for i in range(5):
    rfn = rf_bestScores[k:k+5]
    k+=5
    rf_avgs.append(np.average(rfn))
  

# save each random states averages to the score dict 
score_dict['Random Forest'] = rf_avgs

# %%
print('Model Test Scores:')
score_dict
# Out:
# Model Test Scores:
# {'Lasso': [0.28173612860247454,
#   0.25937279313193673,
#   0.24906539970970298,
#   0.25149432610632483,
#   0.2500200175818385],
#  'Ridge': [0.26834974325425265,
#   0.2498607071922912,
#   0.24269001814201827,
#   0.243566072101859,
#   0.25174291841471147],
#  'Random Forest': [0.27271875837062065,
#   0.2730190240595074,
#   0.26642467472103404,
#   0.28033381453660866,
#   0.27074295404938903]}

# %% [markdown]
# <h2>Support Vector Regressor</h2>

# %%
# create SVR model
from sklearn.svm import SVR

# lists to hold best models and test scores      
svr_bestModels = []
svr_bestScores = []
svr_bestPara = []

# initialize model algo
svr_mod = SVR()

# hyperparameters to tune
param_grid = {
              'svr__gamma': np.logspace(-8,0,15),
              'svr__C': np.logspace(-1,3,15)
              }  

# calculate test scores and find best models for each dataset 
for i in range(num_lags):
    # call function to generate models and store scores
    svr_bestModels, svr_bestScores, svr_bestPara,svr_y_pred = MLpipe_RMSE(X_other_list[i],X_test_list[i],y_other_list[i],
                                                               y_test_list[i],preprocessors[i],all_ps[i],
                                                               svr_mod,param_grid, svr_bestModels,svr_bestScores,
                                                               svr_bestPara)

# print mean and std of test scores
print('Average test score for support vector regressor:',np.average(svr_bestScores))
print('Standard deviation of test scores for support vector regressor:', np.std(svr_bestScores))

# save std and test scores for model 
std_scores['SVR'] = np.std(svr_bestScores)
score_dict['SVR'] = svr_bestScores
results['SVR'] = svr_y_pred

# save model to directory
file = open('../results/svr_model.save', 'wb')
pickle.dump((svr_bestModels[2],X_test_list[2],y_test_list[2]),file)
file.close()

print('\nBest Parameters:')
bp = pd.DataFrame(svr_bestPara)  
bp
# Out:
# Average test score for support vector regressor: 0.25399234747454946
# Standard deviation of test scores for support vector regressor: 0.007726518950287925
#
# Best Parameters:
#         svr__C  svr__gamma
# 0  1000.000000    0.000027
# 1    37.275937    0.000373
# 2   268.269580    0.000100
# 3   517.947468    0.000100
# 4   517.947468    0.000100

# %%
score_dict
# Out:
# {'Lasso': [0.28173612860247454,
#   0.25937279313193673,
#   0.24906539970970298,
#   0.25149432610632483,
#   0.2500200175818385],
#  'Ridge': [0.26834974325425265,
#   0.2498607071922912,
#   0.24269001814201827,
#   0.243566072101859,
#   0.25174291841471147],
#  'Random Forest': [0.27271875837062065,
#   0.2730190240595074,
#   0.26642467472103404,
#   0.28033381453660866,
#   0.27074295404938903],
#  'SVR': [0.26753883027631237,
#   0.24783837951769058,
#   0.2475199248269069,
#   0.24936088568230583,
#   0.25770371706953177]}

# %% [markdown]
# <h2>K-Nearest Neighbor Regressor</h2>

# %%
# create Nearest Neighbor model
from sklearn.neighbors import KNeighborsRegressor

# lists to hold best models and test scores      
k_bestModels = []
k_bestScores = []
k_bestPara = []


# initialize model algo
k_mod = KNeighborsRegressor()

# hyperparameters to tune
param_grid = {
              'kneighborsregressor__n_neighbors': np.linspace(1,10,10,dtype=int), # amount of neighbors to use 
              'kneighborsregressor__weights': ['uniform','distance'] # type of weight to consider
              }  

# calculate test scores and best models for each dataset 
for i in range(num_lags):
    # call function to generate models and store scores
    k_bestModels, k_bestScores, k_bestPara, k_y_pred = MLpipe_RMSE(X_other_list[i],X_test_list[i],y_other_list[i],y_test_list[i],
                                        preprocessors[i],all_ps[i],k_mod,param_grid,
                                        k_bestModels,k_bestScores,k_bestPara)

# print mean and std of test scores
print('Average test score for k-nearest neighbor:',np.average(k_bestScores))
print('Standard deviation of test scores for k-nearest neighbor:', np.std(k_bestScores))

# save scores and std 
std_scores['K Nearest Neighbor'] = np.std(k_bestScores)
score_dict['K Nearest Neighbor'] = k_bestScores
results['K Nearest Neighbor'] = k_y_pred

# save model to directory
file = open('../results/k_model.save', 'wb')
pickle.dump((k_bestModels[2],X_test_list[2],y_test_list[2]),file)
file.close()

print('\nBest Parameters:')
bp = pd.DataFrame(k_bestPara)  
bp
# Out:
# Average test score for k-nearest neighbor: 0.2956400396849529
# Standard deviation of test scores for k-nearest neighbor: 0.004320532201166039
#
# Best Parameters:
#    kneighborsregressor__n_neighbors kneighborsregressor__weights
# 0                                 1                      uniform
# 1                                 1                      uniform
# 2                                 1                      uniform
# 3                                 1                      uniform
# 4                                 1                     distance

# %%
print('Model Test Scores:')
score_dict
# Out:
# Model Test Scores:
# {'Lasso': [0.28173612860247454,
#   0.25937279313193673,
#   0.24906539970970298,
#   0.25149432610632483,
#   0.2500200175818385],
#  'Ridge': [0.26834974325425265,
#   0.2498607071922912,
#   0.24269001814201827,
#   0.243566072101859,
#   0.25174291841471147],
#  'Random Forest': [0.27271875837062065,
#   0.2730190240595074,
#   0.26642467472103404,
#   0.28033381453660866,
#   0.27074295404938903],
#  'SVR': [0.26753883027631237,
#   0.24783837951769058,
#   0.2475199248269069,
#   0.24936088568230583,
#   0.25770371706953177],
#  'K Nearest Neighbor': [0.2939534654625707,
#   0.29086373956135564,
#   0.2948011582883146,
#   0.2948011582883146,
#   0.3037806768242088]}

# %%
# save results dataframe to directory
results_df = pd.DataFrame(results)
results_df.to_csv('../results/results.csv',sep=',')

# %% [markdown]
# <h2>Model Comparison Plot</h2>

# %% [markdown]
# The below plot shows the test scores of the five different models across all time-lagged datasets. From the graphic we can see that all the models, with the exception of Random Forest, perform better as the amount of lags is increased from 1 year to 3 years. However, after 3 years most of the models, with the exception of Lasso, begin to perform worse. The 3 year time-lagged dataset is the optimal dataset for all of the models, except for the K Nearest Neighbor model, which performs the best with the 2 years lagged dataset. Overall, the Ridge model performs the best when compared to all other models.

# %%
# create dataframe with all model results 
final_results = pd.DataFrame(score_dict)
inde = pd.Series([1,2,3,4,5])
final_results.set_index(inde,inplace=True)

# create plots for results 
fig, ax = plt.subplots(figsize=(10, 6))
lineplot = sns.lineplot(final_results)
scatterplot = sns.scatterplot(final_results,s=100,legend=False)

lineplot.set_xticks([1,2,3,4,5])

# lable plot
plt.title('Comparison of Model Test Scores',weight='bold')
plt.xlabel('Amount of Lagged Years',weight='bold')
plt.ylabel('Test Score (RMSE)',weight='bold')
plt.legend(loc='lower left',fontsize = 9)

# save plot to folder
plt.savefig(fname='../figures/model_testscore_comparison',format='png',dpi=300)

plt.show()

# %% [markdown]
# The below graphic plots the true values against the predicted values for the Ridge regressor. From the tight linear plot we can see that the model performs exceptionally well on the test data.

# %%
# create graphic to map the true vs Predicted Values 
plt.scatter(y=results_df['Ridge'],x=y_test)

plt.title('True vs. Predicted Happiness Index',weight='bold')
plt.xlabel('True Index Value',weight='bold')
plt.ylabel('Predicted Index Value',weight='bold')
plt.xlim([2.5,8])
plt.ylim([2.5,8])

# save plot to folder
plt.savefig(fname='../figures/true_predicted_plot',format='png',dpi=300)

plt.show()

# %% [markdown]
# **XGBoost:** The below code creates an XGBoost model for the 3 year lagged dataset. The RMSE score for this model, 0.584, confirms that the Ridge model created above is still the best performing model. Sometimes simplier is better.

# %%
# import needed libraries
import xgboost
from sklearn.model_selection import ParameterGrid
import warnings
warnings.filterwarnings("ignore")

# split the train and val sets 
X_train = X_other_list[2].iloc[:376]
y_train = y_other_list[2].iloc[:376]
X_val = X_other_list[2].iloc[376:]
y_val = y_other_list[2].iloc[376:]


# fit the preprocessor to the train data and transform train, val, and test    
X_train_prep = preprocessors[2].fit_transform(X_train)
X_val_prep = preprocessors[2].transform(X_val)
X_test_prep = preprocessors[2].transform(X_test)

# random states to tune with
seeds = [5,15,25,35,45]
alphas = [0e0, 1e-2, 1e-1, 1e0, 1e1, 1e2]

# parameter grid for model tuning     
grid = {
    "reg_alpha": alphas
   }

# list to save best test scores, all test sets, and best models  
test_scores = []
best_models = []
model_scores = []
std_scores = []

for seed in seeds:
    # list to save scores per random state     
    val_scores = []
    all_models = []
    all_test_scores = []
    
    # loop through and tune alphas
    for j in range(len(alphas)):
        # initialize and set the alpha for xgboost         
        XGB = xgboost.XGBRegressor(random_state=seed)
        XGB.set_params(**ParameterGrid(grid)[j])

        # fit model to the train data, evaluate on the validation set         
        XGB.fit(X_train_prep,y_train,early_stopping_rounds=50,eval_set=[(X_val_prep, y_val)],
                verbose=False)

        # predict the validation and test variables          
        y_val_pred = XGB.predict(X_val_prep)
        y_test_pred = XGB.predict(X_test_prep)

        # add validation and test scores to list          
        val_scores.append(np.sqrt(mean_squared_error(y_val,y_val_pred)))
        all_test_scores.append(np.sqrt(mean_squared_error(y_test,y_test_pred)))
        
        # add all models to list, will tune down to best_models outside hyper loop 
        all_models.append(XGB)

    # find index of best validation score 
    index = np.argmax(val_scores)
    test_scores.append(all_test_scores[index])
    best_models.append(all_models[index])

    # print(test_scores)
    # print(best_models)
    
model_scores.append(np.average(test_scores))
std_scores.append(np.std(test_scores))

print('Mean of the test scores for XGBoost:',np.average(test_scores))
print('Standard deviation of the test scores for XGBoost:',np.std(test_scores))
# Out:
# /opt/anaconda3/envs/data1030/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# Mean of the test scores for XGBoost: 0.5835410475871795
# Standard deviation of the test scores for XGBoost: 0.0

# %% [markdown]
# <h2>Feature Importance Exploration</h2>

# %% [markdown]
# In this section we will explore the level of influence each feature had on our model's predictions. We will discuss global feature importances, which measure each features impact on the predictions of the entire dataset. Additionally, we will explore local feature importance, which looks at how influential each feature was on a specific datapoint's predictions. This examination focuses on the Ridge model for the 3 year lagged dataset, since this was determined to be the best model during our model tuning excerise.

# %% [markdown]
# <h3>Permutation Importance</h3>

# %%
# import needed libraries
from sklearn.inspection import permutation_importance

# best ridge model to use for feature importance and corresponding data test sets 
best_model = l2_bestModels[2]
X_test,y_test = X_test_list[2],y_test_list[2]

# calculate feature permutation importance
ftr_importance = permutation_importance(best_model,X_test,y_test,scoring='neg_root_mean_squared_error',
                                    n_repeats=10, random_state=2)

# save each feature's importance scores over the 10 trials 
importances = ftr_importance.importances

# %%
# feature names 
feature_names = X_test_list[2].columns

# obtain ordered indexes for ascending importance
ascend_ind = np.argsort(np.mean(importances,axis=1))[::-1]

# plot and show graph
plt.rcParams.update({'font.size': 13})
plt.figure(figsize=(10,6))
plt.boxplot(importances[ascend_ind][:10].T,labels=feature_names[ascend_ind][:10],vert=False)
plt.axvline(0,label='change in RMSE without permutation')
plt.title("Permutation Importances of Top 10 Features",weight='bold')
plt.xlabel('Increase in RMSE with Perturbed Feature',weight='bold')
plt.ylabel('Feature',weight='bold')
plt.legend()
plt.tight_layout()

plt.savefig(fname='../figures/permutation_importance',format='png',dpi=300)

plt.show()

# %% [markdown]
# **Permutation Explanation:** The above graphic shows the permutation importance for the top 10 most important features in the 3 year lagged dataset. From this plot we can see that 'Happy lag 1 year,' which is the happiness index of the pervious year, had the strongest influence over the model's predictions. This result makes intuitive sense, as the happiness index of the year prior has a significantly high correlation with the current year's index. Additionally, all of the happiness index features are represented in the top 10 features, meaning that the model can gain the most predictive imformation from knowing a country's past happiness levels.

# %% [markdown]
# <h3>Influential Coefficents</h3>

# %%
# coefficients for the ridge model 
coefs = best_model.best_estimator_[-1].coef_
sorted_indcs = np.argsort(np.abs(coefs))
names = preprocessors[2].fit(X_test).get_feature_names_out()

# plot and label figure 
plt.figure(figsize=(9,6))
plt.rcParams.update({'font.size': 13})
plt.barh(np.arange(10),coefs[sorted_indcs[-10:]])
plt.yticks(np.arange(10),names[sorted_indcs[-10:]])
plt.xlabel('Coefficient Value',weight='bold')
plt.title('Coefficients of Top 10 Features',weight='bold')
plt.tight_layout()

# save figure to fold 
plt.savefig(fname='../figures/coeff_importance',format='png',dpi=300)
plt.show()

# %% [markdown]
# **Coefficient Explanation:** The above plot shows the value of the coefficients for the top 10 features in the Ridge model. From this figure we again see that the Happiness Index lagged 1 year is the most important feature, as the model's coefficent for this feature is 3x greater than the next greatest coefficient. Interestingly, many of the OneHotEncoded country features are appearing in our top 10 coefficients. This means that knowing whether or not a Country is Egypt, Ukraine, Jordan, Tanzania, Georgia, Brazil, Philippines, or Thailand is a major indicator of the given country's happiness index. As a result, we can conclude that happinesss is fairly correlated with country, as the location of a given datapoint explains a significant variations in the model's predictions.

# %% [markdown]
# <h3>SHAP Global Importance</h3>

# %%
# import the shap library
import shap
shap.initjs() # required for visualizations later on

# create the explainer object with the random forest model
explainer = shap.TreeExplainer(XGB)

# preprocess the test set for the shap value calculation 
X_test_prep = preprocessors[2].transform(X_test)

# calculate shap values on the test set
shap_values = explainer.shap_values(X_test_prep)

# create and label shap plot
shap.summary_plot(shap_values, X_test_prep,max_display=10,color_bar=True,show=False,
                  feature_names=names,plot_type='violin')
plt.gcf().axes[-1].set_box_aspect(100)
plt.title('Global SHAP Values for Top 10 Features',weight='bold')
plt.ylabel('Features',weight='bold')
plt.xlabel('SHAP Value (impact on model output)',weight='bold')

plt.savefig(fname='../figures/shap_global',format='png',dpi=300)
plt.show()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# **SHAP Global Values:** The above plot shows the SHAP values for the top 10 most important features in our model's predictions. The graph illustrates the impact of both high and low valued features. For instance, for the most influential feature, Happy lag 1 year, we see that high valued scores had a SHAP value of 0.4. Meanwhile, low valued Happy lag 1 year indexes were almost double as impactful, with a SHAP value near -0.8. This tells us that the model gains a significant amount of information about the certain year's happiness index if the past index was relatively low.

# %% [markdown]
# <h3>SHAP Local Importance</h3>

# %%
# the index of the point to explain
i=90

# plot the force graph for the given point, showing local feature importance
shap.force_plot(explainer.expected_value, shap_values[i], feature_names = names,show=True)
# Out:
# <div id='iEO2NGXE0EGEVBZTS3VB7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
X_test.iloc[90]
# Out:
# Country                      Philippines
# Target Year                         2018
# Population lag 3 years       102113206.0
# Population lag 2 years       103663812.0
# Population lag 1 year        105172921.0
# Population Current           106651394.0
# Life Ex lag 3 years                 67.9
# Life Ex lag 2 years                 68.0
# Life Ex lag 1 year                  68.1
# Life Ex Current                     68.1
# GDP lag 3 years           306446000000.0
# GDP lag 2 years           318627000000.0
# GDP lag 1 year            328481000000.0
# GDP Current               346842000000.0
# GDP_cap lag 3 years          3001.043182
# GDP_cap lag 2 years          3073.654686
# GDP_cap lag 1 year           3123.245642
# GDP_cap Current              3252.110274
# CO2 lag 3 years             2709843495.0
# CO2 lag 2 years             2832080804.0
# CO2 lag 1 year              2966982614.0
# CO2 Current                 3107640835.0
# Happy lag 3 years                5.59427
# ...

# %%
# the index of the point to explain
i=135

# plot the force graph for the given point, showing local feature importance
shap.force_plot(explainer.expected_value, shap_values[i], feature_names = names,show=True)
# Out:
# <div id='iSYM8UTB3WR12K53FL9AW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
X_test.iloc[135]
# Out:
# Country                         Uruguay
# Target Year                        2018
# Population lag 3 years        3412013.0
# Population lag 2 years        3424139.0
# Population lag 1 year         3436645.0
# Population Current            3449290.0
# Life Ex lag 3 years                76.3
# Life Ex lag 2 years                77.0
# Life Ex lag 1 year                 76.5
# Life Ex Current                    76.8
# GDP lag 3 years           53274304222.0
# GDP lag 2 years           57236652490.0
# GDP lag 1 year            64233966861.0
# GDP Current               64515038268.0
# GDP_cap lag 3 years         15613.74597
# GDP_cap lag 2 years         16715.63347
# GDP_cap lag 1 year          18690.89384
# GDP_cap Current             18703.86029
# CO2 lag 3 years             339550899.0
# CO2 lag 2 years             346071339.0
# CO2 lag 1 year              352233912.0
# CO2 Current                 358804882.0
# Happy lag 3 years               6.33601
# ...

# %%
# the index of the point to explain
i=15

# plot the force graph for the given point, showing local feature importance
shap.force_plot(explainer.expected_value, shap_values[i], feature_names = names,show=True)
# Out:
# <div id='iOO1LYSS0MDZ7UUUL7DHN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
X_test.iloc[15]
# Out:
# Country                        Cameroon
# Target Year                        2018
# Population lag 3 years       23298376.0
# Population lag 2 years       23926549.0
# Population lag 1 year        24566070.0
# Population Current           25216261.0
# Life Ex lag 3 years                55.3
# Life Ex lag 2 years                55.6
# Life Ex lag 1 year                 55.9
# Life Ex Current                    56.4
# GDP lag 3 years           32210232912.0
# GDP lag 2 years           33814337900.0
# GDP lag 1 year            36098550142.0
# GDP Current               39973839065.0
# GDP_cap lag 3 years          1382.50979
# GDP_cap lag 2 years         1413.255957
# GDP_cap lag 1 year            1469.4475
# GDP_cap Current             1585.240534
# CO2 lag 3 years             177358737.0
# CO2 lag 2 years             185173931.0
# CO2 lag 1 year              192872431.0
# CO2 Current                 200804389.0
# Happy lag 3 years              5.074051
# ...

# %% [markdown]
# **SHAP Local Values:** The above forceplots show how each feature impacted the prediction for a given datapoint. From the first plot, we can see that the model lowered its prediction because the datapoint in question was from the Phillipines. This tells us that the model has incorporated country specific patterns into its analysis. The last two plots show us that again the Happy lag 1 feature is very influential, as the model used it to raise its predictions for both datapoints. Also we see that the model used the information that the country in question was not Tanzania to raise the value of its prediction for the second plot. Again we see here how the model uses region specific information to make its predictions. Lastly, it is interesting to note that the model does not always rely on the previous years information to make its predictions, but instead determines that further back data, such as year 2 and 3 lags, are more influential for its predictions.
